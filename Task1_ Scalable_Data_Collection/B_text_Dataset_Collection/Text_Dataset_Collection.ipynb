# %%
import os
import requests
import time
from bs4 import BeautifulSoup
from urllib.parse import urljoin
import random
import re

# %%
categories = {
    "Technology": ["https://spectrum.ieee.org/", "https://www.technologyreview.com/", "https://arstechnica.com"],
    "Science": ["https://www.newscientist.com/", "https://phys.org/", "https://www.nature.com"],
    "Health": ["https://www.mayoclinic.org/", "https://www.nih.gov/", "https://www.statnews.com/"],
    "Finance": ["https://www.ft.com/", "https://www.wsj.com/", "https://www.cnbc.com/"],
    "Sports": ["https://theathletic.com/", "https://www.si.com/", "https://sports.yahoo.com/"],
    "Education": ["https://www.insidehighered.com/", "https://www.chronicle.com/", "https://www.edweek.org"],
    "Entertainment": ["https://ew.com/", "https://deadline.com/", "https://www.rollingstone.com"],
    "Gaming": ["https://www.pcgamer.com/", "https://kotaku.com/", "https://www.eurogamer.net/"],
    "Politics": ["https://www.theatlantic.com/", "https://foreignpolicy.com/", "https://www.bbc.com/news/politics"],
    "Travel": ["https://www.travelandleisure.com/", "https://www.nationalgeographic.com/travel", "https://www.cntraveler.com"],
    "Food": ["https://www.eater.com/", "https://www.cooksillustrated.com/", "https://www.seriouseats.com"],
    "Fashion": ["https://wwd.com/", "https://www.thecut.com/", "https://www.gq.com"],
    "Business": ["https://fortune.com/", "https://www.fastcompany.com/", "https://www.economist.com"],
    "Environment": ["https://e360.yale.edu/", "https://grist.org/", "https://www.theguardian.com/environment"],
    "AI and Machine Learning": ["https://www.artificialintelligence-news.com", "https://indiaai.gov.in", "https://aimagazine.com"],
    "Automobiles": ["https://www.caranddriver.com/", "https://www.roadandtrack.com/", "https://www.autoblog.com"],
    "Cryptocurrency": ["https://decrypt.co/", "https://www.blockchainnews.com/", "https://www.cryptonews.com"],
    "History": ["https://www.worldhistory.org", "https://www.historyextra.com/", "https://www.britishmuseum.org/research/british-museum-publications"],
    "Startups": ["https://news.crunchbase.com/", "https://sifted.eu/", "https://www.startupgrind.com"],
    "Cybersecurity": ["https://www.wired.com/category/security/", "https://techcrunch.com/category/security/", "https://www.krebsonsecurity.com"]
}

# %%
output_dir = "text_dataset"
os.makedirs(output_dir, exist_ok=True)

def clean_text(text):
    """Clean and normalize extracted text."""
    text = re.sub(r'\s+', ' ', text)
    text = re.sub(r'[^\w\s.,!?-]', '', text)  
    return text.strip()

def extract_text(url):
    """Extract text content from a webpage and clean it."""
    try:
        headers = {"User-Agent": "Mozilla/5.0"}
        response = requests.get(url, headers=headers, timeout=10)
        response.raise_for_status()
        soup = BeautifulSoup(response.content, 'html.parser')
        text = ' '.join([p.get_text() for p in soup.find_all('p')])
        cleaned_text = clean_text(text)
        return cleaned_text if len(cleaned_text) > 250 else None  
    except Exception as e:
        print(f"Failed to fetch {url}: {e}")
        return None

def get_internal_links(base_url):
    """Fetch internal links from a given website."""
    try:
        headers = {"User-Agent": "Mozilla/5.0"}
        response = requests.get(base_url, headers=headers, timeout=10)
        response.raise_for_status()
        soup = BeautifulSoup(response.content, 'html.parser')
        links = set()
        for link in soup.find_all('a', href=True):
            full_url = urljoin(base_url, link['href'])
            if base_url in full_url:
                links.add(full_url)
        return list(links)[:5] 
    except Exception as e:
        print(f"Error fetching links from {base_url}: {e}")
        return []



for category, websites in categories.items():
    text_file_path = os.path.join(output_dir, f"{category}.txt")
    with open(text_file_path, 'w', encoding='utf-8') as f:
        for website in websites:
            links = get_internal_links(website)
            for link in links:
                print(f"Crawling: {link}")
                text = extract_text(link)
                if text:
                    f.write(text+'\n\n')
                time.sleep(random.uniform(1, 3)) 
    print(f"Completed {category}")


print("Text dataset collection completed!")
# Out:
# Crawling: https://spectrum.ieee.org/decarbonized-future
# Crawling: https://spectrum.ieee.org/topic/careers/
# Crawling: https://spectrum.ieee.org/topic/climate-tech/
# Crawling: https://spectrum.ieee.org/st/join
# Crawling: https://spectrum.ieee.org/the-institute/
# Crawling: https://www.technologyreview.com/2024/11/28/1107511/whats-next-nasas-giant-moon-rocket/
# Crawling: https://www.technologyreview.com/magazines/the-relationships-issue/
# Crawling: https://www.technologyreview.com/privacy/
# Crawling: https://www.technologyreview.com/mit-alumni-news-topics/1865/
# Crawling: https://www.technologyreview.com/2024/02/22/1088768/glowing-plant-lightbio-purple-tomato-norfolk/
# Crawling: https://arstechnica.com/google/2025/03/bad-vibes-google-may-have-screwed-up-haptics-in-the-new-pixel-drop-update/#comments
# Crawling: https://arstechnica.com/newsletters/
# Crawling: https://arstechnica.com/health/2025/03/saliva-that-fights-norovirus-experimental-oral-vaccine-is-nothing-to-spit-at/#comments
# Crawling: https://arstechnica.com/contact-us/
# Crawling: https://arstechnica.com/cars/2025/03/vw-is-testing-its-robotaxis-in-snowy-icy-norway/
# Completed Technology
# Crawling: https://www.newscientist.com/help/
# Crawling: https://www.newscientist.com/article/mg26535310-900-when-did-time-begin-hint-it-wasnt-at-the-big-bang/
# Crawling: https://www.newscientist.com/contact-us/
# Crawling: https://www.newscientist.com/subject/mind/
# Crawling: https://www.newscientist.com/subject/physics/
# Crawling: https://phys.org/news/2025-03-webb-wows-incredible-star.html
# Crawling: https://phys.org/chemistry-news/
# Crawling: https://phys.org/#nav-featured
# Crawling: https://phys.org/earth-news/
# Crawling: https://phys.org/#nav-popular
# Crawling: https://www.nature.com/careers
# Crawling: https://www.nature.com/articles/d41586-025-00634-x
# Crawling: https://www.nature.com/subjects
# Crawling: https://www.nature.com/articles/d41586-025-00719-7
# Crawling: https://www.nature.com/nature/reviews-and-analysis
# Completed Science
# Crawling: https://www.mayoclinic.org/giving-to-mayo-clinic/contact-us
# Crawling: https://www.mayoclinic.org/diseases-conditions/index?letter=T
# Crawling: https://www.mayoclinic.org/diseases-conditions/brain-tumor/care-at-mayo-clinic/mac-20350092
# Crawling: https://www.mayoclinic.org/ar
# Crawling: https://www.mayoclinic.org/medical-professionals
# Crawling: https://www.nih.gov/news-events/nih-research-matters
# Crawling: https://www.nih.gov/institutes-nih/nih-office-director/office-communications-public-liaison/clear-communication/talking-your-doctor
# Crawling: https://www.nih.gov/news-events/nih-research-matters/cancer-cells-can-cooperate-grow
# Crawling: https://www.nih.gov/nih-website-archives
# Crawling: https://www.nih.gov/nondiscrimination-notice
# Crawling: https://www.statnews.com/events/
# Crawling: https://www.statnews.com/2025/03/07/nih-terminates-dei-transgender-related-research-grants/
# Crawling: https://www.statnews.com/topic/chronic-disease/
# Crawling: https://www.statnews.com/pharmalot/2025/03/07/nih-patents-fda-makary-novo-trump-tariffs-bayer-jnj-moderna/
# Crawling: https://www.statnews.com/staff/sarah-todd/
# Completed Health
# Crawling: https://www.ft.com/content/314eb065-5578-4d0c-9517-eb310a69a682
# Crawling: https://www.ft.com/content/ac3e2fd0-4697-48b4-9bf7-6c2d7d02247e
# Crawling: https://www.ft.com/login?location=/
# Crawling: https://www.ft.com/content/e702c71d-a56a-4eda-baad-3800c6ac2a76
# Crawling: https://www.ft.com/world/asia-pacific
# Error fetching links from https://www.wsj.com/: 401 Client Error: HTTP Forbidden for url: https://www.wsj.com/
# Crawling: https://www.cnbc.com/2025/03/07/cramers-lightning-round-rigetti-computing-is-a-meme-stock.html
# Crawling: https://www.cnbc.com/cnbc-disruptors/
# Crawling: https://www.cnbc.com/michael-santoli/
# Crawling: https://www.cnbc.com/2025/01/30/shell-earnings-full-year-and-q4-2024.html
# Crawling: https://www.cnbc.com/converge-live/
# Completed Finance
# Crawling: https://www.si.com/sitemap
# Crawling: https://www.si.com/nfl
# Crawling: https://www.si.com/nba/luka-doncic-hit-in-face-celtics
# Crawling: https://www.si.com/nfl/2025-nfl-draft-quarterback-conundrum-jaxson-dart
# Crawling: https://www.si.com/college-basketball/nc-state-kevin-keatts-fired-less-than-year-after-final-four
# Crawling: https://sports.yahoo.com/college-womens-basketball/standings/
# Crawling: https://sports.yahoo.com/mlb/odds/
# Crawling: https://sports.yahoo.com/soccer/world-cup
# Crawling: https://sports.yahoo.com/college-football/odds/
# Crawling: https://sports.yahoo.com/mlb/topic/postseason/
# Completed Sports
# Crawling: https://www.insidehighered.com/news/diversity/disability
# Crawling: https://www.insidehighered.com/news/quick-takes/2025/03/07/oklahoma-state-improperly-diverted-state-funds-audit-finds
# Crawling: https://www.insidehighered.com/news/tech-innovation/administrative-tech
# Crawling: https://www.insidehighered.com/news/institutions
# Crawling: https://www.insidehighered.com/blogs
# Error fetching links from https://www.chronicle.com/: 403 Client Error: Forbidden for url: https://www.chronicle.com/
# Crawling: https://www.edweek.org/policy-politics
# Crawling: https://www.edweek.org/advertise/quiz/quiz-yourself-how-much-do-you-know-about-the-director-of-pd-persona
# Crawling: https://www.edweek.org/state-of-teaching
# Crawling: https://www.edweek.org/teaching-learning/a-teacher-prep-conference-warned-against-mentioning-dei-presenters-pulled-out/2025/03
# Crawling: https://www.edweek.org/teaching-learning/curriculum
# Completed Education
# Crawling: https://ew.com/amanda-seyfried-dress-fell-apart-boobs-out-in-front-of-glen-powell-11693577
# Crawling: https://ew.com/music/
# Crawling: https://ew.com/yellowjackets/
# Crawling: https://ew.com/genre/sci-fi/
# Crawling: https://ew.com/dwayne-wiggins-dead-tony-toni-tone-co-founder-guitarist-was-64-11693281
# Crawling: https://deadline.com/accessibility/
# Crawling: https://deadline.com/2025/03/hamptons-wildfires-new-york-governor-kathy-hochul-state-of-emergency-1236320132/#comments
# Crawling: https://deadline.com/author/phammond/
# Crawling: https://deadline.com/p/contenders-film-los-angeles/
# Crawling: https://deadline.com/v/film/
# Crawling: https://www.rollingstone.com/author/david-browne/
# Crawling: https://www.rollingstone.com/tv-movies/tv-movie-recaps/
# Crawling: https://www.rollingstone.com/t/photo-gallery/
# Crawling: https://www.rollingstone.com/culture/culture-sports/dana-white-ufc-conquered-america-mma-1235231420/
# Crawling: https://www.rollingstone.com/t/song-to-know/
# Completed Entertainment
# Error fetching links from https://www.pcgamer.com/: HTTPSConnectionPool(host='www.pcgamer.com', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: self-signed certificate in certificate chain (_ssl.c:1000)')))
# Error fetching links from https://kotaku.com/: HTTPSConnectionPool(host='kotaku.com', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: self-signed certificate in certificate chain (_ssl.c:1000)')))
# Error fetching links from https://www.eurogamer.net/: HTTPSConnectionPool(host='www.eurogamer.net', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: self-signed certificate in certificate chain (_ssl.c:1000)')))
# Completed Gaming
# Crawling: https://www.theatlantic.com/culture/archive/2025/03/lady-gaga-saturday-night-live/681981/
# Crawling: https://www.theatlantic.com/politics/archive/2021/03/can-we-get-rid-daylight-saving-time/618281/
# Crawling: https://www.theatlantic.com/most-popular/
# Crawling: https://www.theatlantic.com/author/peter-pomerantsev/
# Crawling: https://www.theatlantic.com/author/mark-leibovich/
# Crawling: https://foreignpolicy.com/2025/02/28/world-war-ii-japan-us-history-atomic-bomb-nuclear-weapons-tokyo-firebombing/
# Crawling: https://foreignpolicy.com/live/fareed-zakaria-looks-ahead-to-2025/
# Crawling: https://foreignpolicy.com/live/insider-access-munich-security-conference/
# Crawling: https://foreignpolicy.com/author/gordon-brown/
# Crawling: https://foreignpolicy.com/author/ivo-h-daalder/
# Crawling: https://www.bbc.com/news/politics#main-content
# Crawling: https://www.bbc.com/news/politics
# Completed Politics
# Crawling: https://www.travelandleisure.com/waldorf-astoria-seychelles-platte-island-8782732
# Crawling: https://www.travelandleisure.com/lost-cultures-living-legacies-new-podcast-trailer-7372691
# Crawling: https://www.travelandleisure.com/
# Crawling: https://www.travelandleisure.com/hail-driver-less-car-waymo-via-uber-austin-texas-11692464
# Crawling: https://www.travelandleisure.com/amazon-best-new-travel-essentials-march-2025-11693332
# Crawling: https://www.nationalgeographic.com/travel?hubmore&page=1&context=eyJjb250ZW50VHlwZSI6IlVuaXNvbkh1YiIsInZhcmlhYmxlcyI6eyJsb2NhdG9yIjoiL3RyYXZlbCIsInBvcnRmb2xpbyI6Im5hdGdlbyIsInF1ZXJ5VHlwZSI6IkxPQ0FUT1IifSwibW9kdWxlSWQiOm51bGx9&id=79ddeec8-a119-4252-aaa8-b306511592e3
# Crawling: https://www.nationalgeographic.com/travel/article/family-friendly-activities-texas
# Crawling: https://www.nationalgeographic.com/travel/article/family-dishes-no-taste-like-home
# Crawling: https://www.nationalgeographic.com/travel
# Crawling: https://www.nationalgeographic.com/travel/destination/destinations
# Crawling: https://www.cntraveler.com/destinations/new-york-city
# Crawling: https://www.cntraveler.com/destinations/mexico-city
# Crawling: https://www.cntraveler.com/gallery/best-hotels-united-states-canada-gold-list
# Crawling: https://www.cntraveler.com/gallery/best-cruise-ships-gold-list
# Crawling: https://www.cntraveler.com/story/winter-gear-shopping-guide
# Completed Travel
# Crawling: https://www.eater.com/gastropod-podcast-episodes
# Crawling: https://www.eater.com/24349457/trump-tariffs-canada-mexico-food-costs-explained
# Crawling: https://www.eater.com/pages/newsletter
# Crawling: https://www.eater.com/best-new-restaurants
# Crawling: https://www.eater.com/authors/bettina-makalintal
# Crawling: https://www.cooksillustrated.com/cookscountry
# Failed to fetch https://www.cooksillustrated.com/cookscountry: 404 Client Error: Not Found for url: https://www.americastestkitchen.com/cooksillustrated/cookscountry
# Crawling: https://www.cooksillustrated.com/recipes/11061-vietnamese-grilled-pork-patties-with-rice-noodles-and-salad-bun-cha
# Crawling: https://www.cooksillustrated.com/recipes/10011-caramelized-onions
# Crawling: https://www.cooksillustrated.com/recipes/10261-skillet-roasted-brussels-sprouts-with-chile-peanuts-and-mint
# Crawling: https://www.cooksillustrated.com/recipes/12219-cast-iron-pan-pizza
# Crawling: https://www.seriouseats.com/tools-gadgets-5118041
# Crawling: https://www.seriouseats.com/science-behind-double-dipping-8787002
# Crawling: https://www.seriouseats.com/amanda-suarez-5221998
# Crawling: https://www.seriouseats.com/how-to-pasteurize-eggs-8675279
# Crawling: https://www.seriouseats.com/electric-appliances-5118048
# Completed Food
# Crawling: https://wwd.com/sustainability/innovation/kering-generation-award-saudi-arabia-1236703704/
# Crawling: https://wwd.com/accessories-news/footwear/
# Crawling: https://wwd.com/runway/fall-2025/paris/ann-demeulemeester/review/
# Crawling: https://wwd.com/business-news/markets/
# Crawling: https://wwd.com/runway/fall-2025/paris/comme-des-garcons/review/
# Crawling: https://www.thecut.com/article/advice-my-friends-abandoned-me-when-they-had-kids.html
# Crawling: https://www.thecut.com/self
# Crawling: https://www.thecut.com/parenting/
# Crawling: https://www.thecut.com/music/
# Crawling: https://www.thecut.com/article/who-is-post-malones-new-girlfriend-christy-lee.html
# Crawling: https://www.gq.com/story/best-greens-powders
# Crawling: https://www.gq.com/story/old-money-style-aesthetic-explainer-1
# Crawling: https://www.gq.com/info/about-gq
# Crawling: https://www.gq.com.tw/
# Crawling: https://www.gq.com/style
# Completed Fashion
# Crawling: https://fortune.com/tag/chro-daily/
# Crawling: https://fortune.com/2025/01/22/greg-abel-berkshire-hathaway-warren-buffett-ceo-succession/
# Crawling: https://fortune.com/2025/02/06/mastercard-share-price-all-time-high-services/
# Crawling: https://fortune.com/analytics
# Crawling: https://fortune.com/author/angela-chitkara/
# Error fetching links from https://www.fastcompany.com/: 403 Client Error: Forbidden for url: https://www.fastcompany.com/
# Crawling: https://www.economist.com/
# Crawling: https://www.economist.com/topics/culture
# Crawling: https://www.economist.com/the-americas
# Crawling: https://www.economist.com/get-the-espresso-app
# Crawling: https://www.economist.com/business/2025/03/06/mistral-europes-biggest-ai-startup-is-blowing-hot
# Completed Business
# Crawling: https://e360.yale.edu/topics/solutions
# Crawling: https://e360.yale.edu/features/tigris-euphrates-photo-essay
# Crawling: https://e360.yale.edu/features/climate-change-drinking-water
# Crawling: https://e360.yale.edu/topics/biodiversity
# Crawling: https://e360.yale.edu/about#contact
# Crawling: https://grist.org/wildfires/altadena-eaton-fire-recovery-housing-plan/
# Crawling: https://grist.org/indigenous/its-about-control-why-trump-renamed-denali-to-mount-mckinley/
# Crawling: https://grist.org/climate-fiction/imagine2200-the-isle-of-beautiful-waters/
# Crawling: https://grist.org/author/emily-pontecorvo/
# Crawling: https://grist.org/video/quitobaquito-springs-national-park-service-border-indigenous-water-protection/
# Crawling: https://www.theguardian.com/environment/pollution
# Crawling: https://www.theguardian.com/environment/series/the-age-of-extinction
# Crawling: https://www.theguardian.com/environment/2025/mar/06/italy-fiumicino-cruise-ship-port-bilancioni-conservation-royal-caribbean
# Crawling: https://www.theguardian.com/environment/series/seascape-the-state-of-our-oceans
# Crawling: https://www.theguardian.com/environment/2025/mar/08/country-diary-dancing-dippers-share-the-secret-of-their-riverbank-nest#comments
# Completed Environment
# Crawling: https://www.artificialintelligence-news.com/categories/development/
# Crawling: https://www.artificialintelligence-news.com/categories/artificial-intelligence/
# Crawling: https://www.artificialintelligence-news.com/categories/ai-enterprise/
# Crawling: https://www.artificialintelligence-news.com/news/endor-labs-ai-transparency-vs-open-washing/
# Crawling: https://www.artificialintelligence-news.com/news/softbank-chief-forget-agi-asi-here-within-10-years/
# Crawling: https://indiaai.gov.in/ai-standards
# Crawling: https://indiaai.gov.in/terms
# Crawling: https://indiaai.gov.in/events
# Crawling: https://indiaai.gov.in/research-reports
# Crawling: https://indiaai.gov.in/datasets
# Error fetching links from https://aimagazine.com: 403 Client Error: Forbidden for url: https://aimagazine.com/
# Completed AI and Machine Learning
# Crawling: https://www.caranddriver.com/rankings/best-luxury-cars
# Crawling: https://www.caranddriver.com/videos/
# Crawling: https://www.caranddriver.com/newsletter
# Crawling: https://www.caranddriver.com/podcasts/
# Crawling: https://www.caranddriver.com/auth/csrf?action=login&return_url=https://www.caranddriver.com/
# Crawling: https://www.roadandtrack.com/exclusives/
# Crawling: https://www.roadandtrack.com/reviews/a63678899/best-grand-touring-cars-pcoty-2025/
# Crawling: https://www.roadandtrack.com/car-culture/a62811453/porsche-930-turbo/
# Crawling: https://www.roadandtrack.com/about/a2923/community-guidelines/
# Crawling: https://www.roadandtrack.com/car-culture/a63289281/car-grudges-column/
# Error fetching links from https://www.autoblog.com: 403 Client Error: Forbidden for url: https://www.autoblog.com/
# Completed Automobiles
# Crawling: https://decrypt.co/price/nervos-network
# Crawling: https://decrypt.co/price/crypto-com
# Crawling: https://decrypt.co/price/binance-coin
# Crawling: https://decrypt.co/309059/popg-expands-its-reach-popg-now-available-on-lbank
# Crawling: https://decrypt.co/price/sweth
# Error fetching links from https://www.blockchainnews.com/: HTTPSConnectionPool(host='www.blockchainnews.com', port=443): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000019DDEFAE8A0>: Failed to resolve 'www.blockchainnews.com' ([Errno 11001] getaddrinfo failed)"))
# Error fetching links from https://www.cryptonews.com: 403 Client Error: Forbidden for url: https://cryptonews.com/
# Completed Cryptocurrency
# Crawling: https://www.worldhistory.org/medialibrary/
# Crawling: https://www.worldhistory.org/static/reports/
# Crawling: https://www.worldhistory.org/membership/?utm_source=whe&utm_campaign=membership&utm_medium=header-nav
# Crawling: https://www.worldhistory.org/edu/collections/
# Crawling: https://www.worldhistory.org/xres/
# Crawling: https://www.historyextra.com/academy/witchcraft-course/
# Crawling: https://www.historyextra.com/academy/victorian-life
# Crawling: https://www.historyextra.com/period/20th-century/champagne-socialist-meaning-origin/
# Crawling: https://www.historyextra.com/topic/military-history/
# Crawling: https://www.historyextra.com/topic/
# Error fetching links from https://www.britishmuseum.org/research/british-museum-publications: 403 Client Error: Forbidden for url: https://www.britishmuseum.org/research/british-museum-publications
# Completed History
# Crawling: https://news.crunchbase.com/sections/clean-tech-and-energy/
# Crawling: https://news.crunchbase.com/unicorn-company-list/
# Crawling: https://news.crunchbase.com/venture/european-funding-recap-q1-2024/
# Crawling: https://news.crunchbase.com/ai/valuation-escalation-february-2025-openai-anthropic/
# Crawling: https://news.crunchbase.com/health-wellness-biotech/new-unicorn-startups-january-2025-hippocratic-ai-mercor/
# Error fetching links from https://sifted.eu/: 403 Client Error: Forbidden for url: https://sifted.eu/
# Crawling: https://www.startupgrind.com/speak?utm_source=website&utm_medium=navigation
# Crawling: https://www.startupgrind.com/
# Crawling: https://www.startupgrind.com
# Crawling: https://www.startupgrind.com/jobs?utm_source=website&utm_medium=navigation
# Crawling: https://www.startupgrind.com/terms-of-service/
# Completed Startups
# Crawling: https://www.wired.com/category/security/
# Crawling: https://www.wired.com/category/security/security-advice/
# Crawling: https://www.wired.com/category/security/privacy/
# Crawling: https://www.wired.com/category/security/security-news/
# Crawling: https://www.wired.com/category/security/cyberattacks-hacks/
# Crawling: https://techcrunch.com/category/security/page/2/
# Crawling: https://techcrunch.com/category/security/
# Crawling: https://www.krebsonsecurity.com#content
# Crawling: https://www.krebsonsecurity.com/subscribe/
# Completed Cybersecurity
# Text dataset collection completed!
